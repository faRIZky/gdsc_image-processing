# %%
# !pip install ultralytics

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="nUoiHQdtEhNt9cAm8UFL")
project = rf.workspace("the-polytechnic-university-of-timisoara").project("animals-class")
version = project.version(1)
dataset = version.download("folder")
# Out:
# mkdir: cannot create directory ‘{HOME}/datasets’: No such file or directory
# [Errno 2] No such file or directory: '{HOME}/datasets'
# /content
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# %cd {HOME}

# !yolo task=classify mode=train model=yolov8n-cls.pt data={dataset.location} epochs=30 imgsz=128
# Out:
# [Errno 2] No such file or directory: '{HOME}'
# /content
# New https://pypi.org/project/ultralytics/8.2.63 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.62 🚀 Python-3.10.12 torch-2.3.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !yolo task=classify mode=predict model=/content/runs/classify/train4/weights/best.pt conf=0.25 source=/content/images.jpeg
# Out:
# Ultralytics YOLOv8.2.62 🚀 Python-3.10.12 torch-2.3.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n-cls summary (fused): 73 layers, 1,437,442 parameters, 0 gradients, 3.3 GFLOPs
#
# image 1/1 /content/images.jpeg: 128x128 dog 0.89, cat 0.11, 14.7ms
# Speed: 8.8ms preprocess, 14.7ms inference, 0.1ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs/classify/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# dog 0.89, cat 0.11, --> predict foto dog. benar.
